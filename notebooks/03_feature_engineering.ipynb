# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Cleaned Dataset

# %%
df = pd.read_csv("../data/processed/clean_telco_churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0             0            No             DSL             No          Yes
# 1             1            No             DSL            Yes           No
# 2             1            No             DSL            Yes          Yes
# 3             0            No             DSL            Yes           No
# 4             1            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#    PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0                 1           Electronic check           29.85        29.85
# 1                 0               Mailed check           56.95       1889.5
# 2                 1               Mailed check           53.85       108.15
# 3                 0  Bank transfer (automatic)           42.30      1840.75
# 4                 1           Electronic check           70.70       151.65
#
#    Churn   TenureGroup
# 0      0   0-12 months
# 1      0  24-48 months
# 2      1   0-12 months
# 3      0  24-48 months
# 4      1   0-12 months

# %% [markdown]
# ## Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   int64
#  21  TenureGroup       7043 non-null   object
# dtypes: float64(1), int64(7), object(14)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Reconfirm Numeric Columns

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   int64
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   int64
#  21  TenureGroup       7043 non-null   object
# dtypes: float64(2), int64(7), object(13)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Drop Customer ID (Not Useful for Modeling)

# %%
df = df.drop("customerID", axis=1)

# %% [markdown]
# ## Encode Categorical Variables

# %%
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# ## Separate Features & Target

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %% [markdown]
# ## Feature Scaling (Important for Logistic Regression)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\shaik aslam\appdata\local\programs\python\python312\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\shaik aslam\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\shaik aslam\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\shaik aslam\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\shaik aslam\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\SHAIK ASLAM\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 📊 Feature Engineering — Key Insights
#
# * Converted categorical variables into numeric using One-Hot Encoding
# * Used `drop_first=True` to avoid multicollinearity
# * Removed `customerID` as it has no predictive value
# * Converted `TotalCharges` to numeric format
# * Split data into features (X) and target (y)
# * Applied StandardScaler for feature scaling
# * Ensured all features are on the same scale for better model performance
#
# ---
#
# ### ✅ Conclusion
#
# Data is cleaned, transformed, and ready for machine learning.
